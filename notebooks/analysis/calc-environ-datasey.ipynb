# %%
import pandas as pd
import numpy as np
from IPython.display import clear_output

from astropy.io import fits
from astropy.table import Table
from astropy.cosmology import FlatLambdaCDM
from astropy.coordinates import SkyCoord
import astropy.units as u

import sys
import os
import glob
from tqdm import tqdm
tqdm.pandas()

# %%
folder = 'C:/Users/oryan/Documents/mergers-in-cosmos'
data_folder = f'{folder}/data'
results = f'{folder}/results'

drive_folder = 'E:/cosmos-data'

# %%
with fits.open(f'{drive_folder}/COSMOS2020_CLASSIC_R1_v2.1_p3.fits.gz') as hdul:
    data_rec = hdul[1].data

# %%
data_rec[~np.isnan(data_rec['HSC_r_MAG_ISO'])]

# %%
data_rec.columns
# Out:
# ColDefs(
#     name = 'ID'; format = 'K'
#     name = 'ALPHA_J2000'; format = 'D'; unit = 'deg'
#     name = 'DELTA_J2000'; format = 'D'; unit = 'deg'
#     name = 'X_IMAGE'; format = 'D'; unit = 'pix'
#     name = 'Y_IMAGE'; format = 'D'; unit = 'pix'
#     name = 'ERRX2_IMAGE'; format = 'D'; unit = 'pix**2'
#     name = 'ERRY2_IMAGE'; format = 'D'; unit = 'pix**2'
#     name = 'ERRXY_IMAGE'; format = 'D'; unit = 'pix**2'
#     name = 'FLUX_RADIUS'; format = 'E'; unit = 'pix'
#     name = 'KRON_RADIUS'; format = 'E'
#     name = 'FLAG_HSC'; format = 'I'
#     name = 'FLAG_SUPCAM'; format = 'I'
#     name = 'FLAG_UVISTA'; format = 'I'
#     name = 'FLAG_UDEEP'; format = 'I'
#     name = 'FLAG_COMBINED'; format = 'I'
#     name = 'EBV_MW'; format = 'D'
#     name = 'CFHT_u_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_u_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_u_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_u_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_u_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_u_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_u_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_u_FLAGS'; format = 'I'; null = -99
#     name = 'CFHT_u_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'CFHT_ustar_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_ustar_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_ustar_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_ustar_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_ustar_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_ustar_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'CFHT_ustar_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'CFHT_ustar_FLAGS'; format = 'I'; null = -99
#     name = 'CFHT_ustar_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'HSC_g_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_g_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_g_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_g_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_g_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_g_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_g_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_g_FLAGS'; format = 'I'; null = -99
#     name = 'HSC_g_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'HSC_r_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_r_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_r_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_r_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_r_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_r_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_r_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_r_FLAGS'; format = 'I'; null = -99
#     name = 'HSC_r_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'HSC_i_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_i_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_i_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_i_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_i_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_i_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_i_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_i_FLAGS'; format = 'I'; null = -99
#     name = 'HSC_i_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'HSC_z_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_z_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_z_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_z_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_z_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_z_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_z_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_z_FLAGS'; format = 'I'; null = -99
#     name = 'HSC_z_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'HSC_y_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_y_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'HSC_y_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_y_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'HSC_y_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_y_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'HSC_y_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'HSC_y_FLAGS'; format = 'I'; null = -99
#     name = 'HSC_y_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'UVISTA_Y_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Y_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Y_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Y_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Y_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Y_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Y_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Y_FLAGS'; format = 'I'; null = -99
#     name = 'UVISTA_Y_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'UVISTA_J_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_J_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_J_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_J_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_J_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_J_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_J_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_J_FLAGS'; format = 'I'; null = -99
#     name = 'UVISTA_J_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'UVISTA_H_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_H_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_H_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_H_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_H_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_H_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_H_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_H_FLAGS'; format = 'I'; null = -99
#     name = 'UVISTA_H_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'UVISTA_Ks_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Ks_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Ks_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Ks_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Ks_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Ks_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_Ks_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_Ks_FLAGS'; format = 'I'; null = -99
#     name = 'UVISTA_Ks_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IB427_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB427_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB427_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB427_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB427_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB427_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB427_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB427_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IB427_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IB464_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB464_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB464_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB464_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB464_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB464_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB464_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB464_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IB464_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IA484_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA484_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA484_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA484_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA484_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA484_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA484_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA484_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IA484_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IB505_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB505_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB505_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB505_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB505_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB505_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB505_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB505_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IB505_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IA527_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA527_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA527_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA527_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA527_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA527_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA527_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA527_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IA527_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IB574_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB574_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB574_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB574_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB574_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB574_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB574_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB574_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IB574_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IA624_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA624_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA624_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA624_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA624_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA624_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA624_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA624_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IA624_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IA679_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA679_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA679_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA679_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA679_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA679_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA679_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA679_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IA679_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IB709_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB709_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB709_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB709_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB709_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB709_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB709_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB709_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IB709_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IA738_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA738_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA738_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA738_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA738_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA738_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA738_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA738_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IA738_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IA767_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA767_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA767_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA767_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA767_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA767_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IA767_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IA767_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IA767_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_IB827_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB827_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB827_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB827_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB827_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB827_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_IB827_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_IB827_FLAGS'; format = 'I'; null = -99
#     name = 'SC_IB827_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_NB711_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB711_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB711_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB711_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB711_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB711_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB711_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB711_FLAGS'; format = 'I'; null = -99
#     name = 'SC_NB711_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_NB816_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB816_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB816_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB816_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB816_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB816_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_NB816_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_NB816_FLAGS'; format = 'I'; null = -99
#     name = 'SC_NB816_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'UVISTA_NB118_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_NB118_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_NB118_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_NB118_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_NB118_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_NB118_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'UVISTA_NB118_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'UVISTA_NB118_FLAGS'; format = 'I'; null = -99
#     name = 'UVISTA_NB118_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_B_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_B_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_B_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_B_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_B_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_B_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_B_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_B_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_B_FLAGS'; format = 'I'; null = -99
#     name = 'SC_B_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_gp_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_gp_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_gp_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_gp_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_gp_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_gp_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_gp_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_gp_FLAGS'; format = 'I'; null = -99
#     name = 'SC_gp_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_V_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_V_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_V_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_V_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_V_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_V_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_V_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_V_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_V_FLAGS'; format = 'I'; null = -99
#     name = 'SC_V_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_rp_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_rp_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_rp_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_rp_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_rp_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_rp_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_rp_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_rp_FLAGS'; format = 'I'; null = -99
#     name = 'SC_rp_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_ip_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_ip_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_ip_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_ip_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_ip_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_ip_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_ip_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_ip_FLAGS'; format = 'I'; null = -99
#     name = 'SC_ip_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_zp_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_zp_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_zp_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_zp_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_zp_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_zp_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_zp_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_zp_FLAGS'; format = 'I'; null = -99
#     name = 'SC_zp_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'SC_zpp_FLUX_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_zpp_FLUXERR_APER2'; format = 'E'; unit = 'uJy'
#     name = 'SC_zpp_FLUX_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_zpp_FLUXERR_APER3'; format = 'E'; unit = 'uJy'
#     name = 'SC_zpp_FLUX_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_zpp_FLUXERR_AUTO'; format = 'E'; unit = 'uJy'
#     name = 'SC_zpp_MAG_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAGERR_APER2'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAG_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAGERR_APER3'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAG_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAGERR_AUTO'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAG_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_MAGERR_ISO'; format = 'E'; unit = 'mag'
#     name = 'SC_zpp_FLAGS'; format = 'I'; null = -99
#     name = 'SC_zpp_IMAFLAGS_ISO'; format = 'I'; null = -99
#     name = 'total_off2'; format = 'E'; unit = 'mag'
#     name = 'total_off3'; format = 'E'; unit = 'mag'
#     name = 'IRAC_CH1_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'IRAC_CH1_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'IRAC_CH1_MAG'; format = 'E'; unit = 'mag'
#     name = 'IRAC_CH1_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'IRAC_CH2_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'IRAC_CH2_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'IRAC_CH2_MAG'; format = 'E'; unit = 'mag'
#     name = 'IRAC_CH2_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'ID_GALEX'; format = 'K'; null = -99
#     name = 'GALEX_FUV_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'GALEX_FUV_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'GALEX_FUV_MAG'; format = 'E'; unit = 'mag'
#     name = 'GALEX_FUV_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'GALEX_NUV_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'GALEX_NUV_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'GALEX_NUV_MAG'; format = 'E'; unit = 'mag'
#     name = 'GALEX_NUV_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'ID_COSMOS2015'; format = 'K'; null = -99
#     name = 'SPLASH_CH1_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH1_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH1_MAG'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH1_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH2_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH2_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH2_MAG'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH2_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH3_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH3_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH3_MAG'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH3_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH4_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH4_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'SPLASH_CH4_MAG'; format = 'E'; unit = 'mag'
#     name = 'SPLASH_CH4_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'ID_ACS'; format = 'K'; null = -99
#     name = 'ACS_F814W_FLUX'; format = 'E'; unit = 'uJy'
#     name = 'ACS_F814W_FLUXERR'; format = 'E'; unit = 'uJy'
#     name = 'ACS_F814W_MAG'; format = 'E'; unit = 'mag'
#     name = 'ACS_F814W_MAGERR'; format = 'E'; unit = 'mag'
#     name = 'ACS_A_WORLD'; format = 'E'; unit = 'deg'
#     name = 'ACS_B_WORLD'; format = 'E'; unit = 'deg'
#     name = 'ACS_THETA_WORLD'; format = 'E'; unit = 'deg'
#     name = 'ACS_FWHM_WORLD'; format = 'E'; unit = 'deg'
#     name = 'ACS_MU_MAX'; format = 'E'; unit = 'mag'
#     name = 'ACS_MU_CLASS'; format = 'E'
#     name = 'ID_CHANDRA'; format = '9A'
#     name = 'ID_FARMER'; format = 'K'; null = -99
#     name = 'lp_zBEST'; format = 'D'
#     name = 'lp_type'; format = 'K'; null = -99
#     name = 'lp_zPDF'; format = 'D'
#     name = 'lp_zPDF_l68'; format = 'D'
#     name = 'lp_zPDF_u68'; format = 'D'
#     name = 'lp_zMinChi2'; format = 'D'
#     name = 'lp_chi2_best'; format = 'D'
#     name = 'lp_zp_2'; format = 'D'
#     name = 'lp_chi2_2'; format = 'D'
#     name = 'lp_NbFilt'; format = 'K'; null = -99
#     name = 'lp_zq'; format = 'D'
#     name = 'lp_chiq'; format = 'D'
#     name = 'lp_modq'; format = 'D'
#     name = 'lp_mods'; format = 'D'
#     name = 'lp_chis'; format = 'D'
#     name = 'lp_mask'; format = 'D'
#     name = 'lp_model'; format = 'K'; null = -99
#     name = 'lp_age'; format = 'D'; unit = 'yr'
#     name = 'lp_dust'; format = 'D'
#     name = 'lp_Attenuation'; format = 'K'; null = -99
#     name = 'lp_MFUV'; format = 'D'; unit = 'mag'
#     name = 'lp_MNUV'; format = 'D'; unit = 'mag'
#     name = 'lp_MU'; format = 'D'; unit = 'mag'
#     name = 'lp_MG'; format = 'D'; unit = 'mag'
#     name = 'lp_MR'; format = 'D'; unit = 'mag'
#     name = 'lp_MI'; format = 'D'; unit = 'mag'
#     name = 'lp_MZ'; format = 'D'; unit = 'mag'
#     name = 'lp_MY'; format = 'D'; unit = 'mag'
#     name = 'lp_MJ'; format = 'D'; unit = 'mag'
#     name = 'lp_MH'; format = 'D'; unit = 'mag'
#     name = 'lp_MK'; format = 'D'; unit = 'mag'
#     name = 'lp_mass_med'; format = 'D'; unit = 'log(solMass)'
#     name = 'lp_mass_med_min68'; format = 'D'; unit = 'log(solMass)'
#     name = 'lp_mass_med_max68'; format = 'D'; unit = 'log(solMass)'
#     name = 'lp_mass_best'; format = 'D'; unit = 'log(solMass)'
#     name = 'lp_SFR_med'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'lp_SFR_med_min68'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'lp_SFR_med_max68'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'lp_SFR_best'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'lp_sSFR_med'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'lp_sSFR_med_min68'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'lp_sSFR_med_max68'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'lp_sSFR_best'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'ez_z_phot'; format = 'E'
#     name = 'ez_z_phot_chi2'; format = 'E'
#     name = 'ez_z_phot_risk'; format = 'E'
#     name = 'ez_z_min_risk'; format = 'E'
#     name = 'ez_min_risk'; format = 'E'
#     name = 'ez_z_raw_chi2'; format = 'E'
#     name = 'ez_raw_chi2'; format = 'E'; disp = 'F8.4'
#     name = 'ez_z025'; format = 'E'; disp = 'F8.4'
#     name = 'ez_z160'; format = 'E'; disp = 'F8.4'
#     name = 'ez_z500'; format = 'E'; disp = 'F8.4'
#     name = 'ez_z840'; format = 'E'; disp = 'F8.4'
#     name = 'ez_z975'; format = 'E'; disp = 'F8.4'
#     name = 'ez_nusefilt'; format = 'K'; null = -99
#     name = 'ez_lc_min'; format = 'D'; unit = 'Angstrom'; disp = 'F10.1'
#     name = 'ez_lc_max'; format = 'D'; unit = 'Angstrom'; disp = 'F10.1'
#     name = 'ez_star_min_chi2'; format = 'E'; disp = 'F10.1'
#     name = 'ez_star_teff'; format = 'K'; unit = 'K'; null = -99
#     name = 'ez_restU'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restU_err'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restB'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restB_err'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restV'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restV_err'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restJ'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_restJ_err'; format = 'E'; unit = 'uJy'; disp = 'F12.3'
#     name = 'ez_dL'; format = 'D'; unit = 'Mpc'; disp = 'E9.1'
#     name = 'ez_mass'; format = 'D'; unit = 'log(solMass)'; disp = 'E10.2'
#     name = 'ez_sfr'; format = 'D'; unit = 'log(solMass/yr)'; disp = 'F12.3'
#     name = 'ez_ssfr'; format = 'D'; unit = 'log(yr**(-1))'; disp = 'F12.3'
#     name = 'ez_Lv'; format = 'D'; unit = 'log(solLum)'; disp = 'E10.2'
#     name = 'ez_LIR'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_energy_abs'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_Lu'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_Lj'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_L1400'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_L2800'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_LHa'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_LOIII'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_LHb'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_LOII'; format = 'D'; unit = 'solLum'; disp = 'E10.2'
#     name = 'ez_MLv'; format = 'D'; unit = 'solMass/solLum'; disp = 'F11.2'
#     name = 'ez_Av'; format = 'D'; unit = 'mag'; disp = 'F11.2'
#     name = 'ez_lwAgeV'; format = 'D'; unit = 'Gyr'; disp = 'F11.2'
#     name = 'ez_mass_p025'; format = 'D'; unit = 'log(solMass)'
#     name = 'ez_mass_p160'; format = 'D'; unit = 'log(solMass)'
#     name = 'ez_mass_p500'; format = 'D'; unit = 'log(solMass)'
#     name = 'ez_mass_p840'; format = 'D'; unit = 'log(solMass)'
#     name = 'ez_mass_p975'; format = 'D'; unit = 'log(solMass)'
#     name = 'ez_sfr_p025'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'ez_sfr_p160'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'ez_sfr_p500'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'ez_sfr_p840'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'ez_sfr_p975'; format = 'D'; unit = 'log(solMass/yr)'
#     name = 'ez_Lv_p025'; format = 'D'; unit = 'log(solLum)'
#     name = 'ez_Lv_p160'; format = 'D'; unit = 'log(solLum)'
#     name = 'ez_Lv_p500'; format = 'D'; unit = 'log(solLum)'
#     name = 'ez_Lv_p840'; format = 'D'; unit = 'log(solLum)'
#     name = 'ez_Lv_p975'; format = 'D'; unit = 'log(solLum)'
#     name = 'ez_LIR_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_LIR_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_LIR_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_LIR_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_LIR_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_energy_abs_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_energy_abs_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_energy_abs_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_energy_abs_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_energy_abs_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lu_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lu_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lu_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lu_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lu_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lj_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lj_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lj_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lj_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_Lj_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_L1400_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_L1400_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_L1400_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_L1400_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_L1400_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_L2800_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_L2800_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_L2800_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_L2800_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_L2800_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHa_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHa_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHa_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHa_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHa_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOIII_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOIII_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOIII_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOIII_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOIII_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHb_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHb_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHb_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHb_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_LHb_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOII_p025'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOII_p160'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOII_p500'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOII_p840'; format = 'D'; unit = 'solLum'
#     name = 'ez_LOII_p975'; format = 'D'; unit = 'solLum'
#     name = 'ez_ssfr_p025'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'ez_ssfr_p160'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'ez_ssfr_p500'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'ez_ssfr_p840'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'ez_ssfr_p975'; format = 'D'; unit = 'log(yr**(-1))'
#     name = 'ez_Av_p025'; format = 'D'; unit = 'mag'
#     name = 'ez_Av_p160'; format = 'D'; unit = 'mag'
#     name = 'ez_Av_p500'; format = 'D'; unit = 'mag'
#     name = 'ez_Av_p840'; format = 'D'; unit = 'mag'
#     name = 'ez_Av_p975'; format = 'D'; unit = 'mag'
# )

# %%
data_rec = data_rec[data_rec['lp_type'] == 0]

# %%
data_tab = Table(data_rec)

# %%
data = data_tab['ID', 'ALPHA_J2000', 'DELTA_J2000', 'ez_z_phot']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11836\2943168286.py in <module>
# ----> 1 data = data_tab['ID', 'ALPHA_J2000', 'DELTA_J2000', 'ez_z_phot']
#
# NameError: name 'data_tab' is not defined

# %%
del data_tab

# %%
del data_rec

# %%
ids = list(data['ID'])

# %%
def calc_sep(ra1, dec1, ra2, dec2, conversion):
    
    c1 = SkyCoord(ra = ra1 * u.deg, dec = dec1 * u.deg, frame = 'fk5')
    c2 = SkyCoord(ra = ra2 * u.deg, dec = dec2 * u.deg, frame = 'fk5')
    
    ang_sep = c1.separation(c2).to(u.arcmin)
        
    proj_sep = ang_sep * conversion
    
    return float(proj_sep.to(u.Mpc) / u.Mpc)

# %%
ang = 0.1
cosmo = FlatLambdaCDM(H0=70, Om0=0.3, Tcmb0=2.725)
results_dict = {}
counter = 0

for i in tqdm(ids):
    tmp_dict = {'IDs': [], 'N_1': np.nan, 'N_2': np.nan, 'N_3': np.nan, 'N_4': np.nan, 'N_5': np.nan}
    entry = data[data['ID'] == i]
    if np.isnan(entry['ALPHA_J2000']) or np.isnan(entry['DELTA_J2000']) or np.isnan(entry['ez_z_phot']):
        continue
    
    ra = entry['ALPHA_J2000']
    dec = entry['DELTA_J2000']
    z_phot = entry['ez_z_phot']
    conversion = cosmo.kpc_proper_per_arcmin(z_phot)

    
    record = data[(data['ALPHA_J2000'] < (ra + ang)) & (data['ALPHA_J2000'] > (ra - ang)) & (data['DELTA_J2000'] < (dec + ang)) & (data['DELTA_J2000'] > (dec - ang))]
    record = record[record['ID'] != i]
    
    record = record[(record['ez_z_phot'] > z_phot - 0.005) & (record['ez_z_phot'] < z_phot + 0.005)]
    
    record_df = record.to_pandas()
    
    if len(record_df) == 0.0:
        results_dict[i] = tmp_dict
        continue
    
    record_df = (
        record_df
        .assign(seperations = record_df.apply(lambda row: calc_sep(ra, dec, row.ALPHA_J2000, row.DELTA_J2000, conversion), axis = 1))
    )
    
    record_df = record_df.sort_values('seperations', ascending = True)
    
    record_df = record_df[:5][['ID', 'seperations']]
        
    for j in range(len(record_df)):
        tmp_dict['IDs'].append(record_df.ID.iloc[j])
        tmp_dict[f'N_{j+1}'] = j+1 / (np.pi * (record_df.seperations.iloc[j])**2)
        
    results_dict[i] = tmp_dict
    
    if len(results_dict) > 50000:
        results_df = pd.DataFrame.from_dict(results_dict, orient = 'index').reset_index().rename(columns = {'index' : 'ID'})
        
        results_df.to_csv(f'{results}/full-sample-{counter * 50}-{(counter + 1) * 50}.csv')
        
        counter += 1
        results_dict = {}
        del results_df
# Out:
#   0%|          | 51/1677646 [00:04<43:31:43, 10.71it/s]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
csv_files = glob.glob(f'{results}/full-sample-*-*.csv')

# %%
for counter, i in enumerate(csv_files):
    if counter == 0:
        df = pd.read_csv(i, index_col = 0)
        continue
    df_tmp = pd.read_csv(i, index_col = 0)
    df = pd.concat([df, df_tmp])
    
df.to_csv(f'{results}/full-sample-all.csv')
